# %%
from datasets import load_dataset

# %%
am_products= load_dataset("bprateek/amazon_product_description")

# %%
for split, split_dataset in am_products.items():
    split_dataset.to_json(f"product-{split}.jsonl")

# %%
am_products['train'].to_json("am_products.jsonl")

# %% [markdown]
# #### Alternate way of doing it if the above fails. You should see 10002 product files

# %%
# import json
# json_dict = am_products['train'].to_dict()
# with open('am_products.json', 'w') as f:
#     f.write(json.dumps(json_dict, indent=2), "utf-8")
